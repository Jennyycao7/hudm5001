# %%
import sqlite3

# %% [markdown]
# 2. Creating dataset

# %%
emotions = ['grief','overstimulated','emptiness','stress','lonely']
frequency = [4,7,3,5,3]
intensity = [10.0,6,4,8.5,5.34]
dataset = list(zip(emotions,frequency,intensity))

# %%
dataset
# Out:
# [('grief', 4, 10.0),
#  ('overstimulated', 7, 6),
#  ('emptiness', 3, 4),
#  ('stress', 5, 8.5),
#  ('lonely', 3, 5.34)]

# %% [markdown]
# 3. Create table

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path_to_db = "/Users/jeffe/sqlite/mydata.db"

# %%
# create db connection
conn = sqlite3.connect(path_to_db)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipython-input-1033792547.py in <cell line: 0>()
#       1 # create db connection
# ----> 2 conn = sqlite3.connect(path_to_db)
#
# OperationalError: unable to open database file
